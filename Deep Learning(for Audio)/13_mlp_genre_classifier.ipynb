# %% [markdown]
# # Implementing a neural network for music genre classification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# path to json file that stores MFCCs and genre labels for each porcessed segment
DATASET_PATH = "/content/drive/MyDrive/DL_for_Audio/data/json/data.json"  

def load_data(dataset_path):
  """Loads training dataset from json file.

      :param data_path (str) : path to json file containing data
      :return X (ndarray) : Inputs
      :return Y (ndarray) : Targets
  """
  
  with open(dataset_path, "r") as fp:
    data = json.load(fp)

  # convert lists into numpy arrays
  X = np.array(data["mfcc"])          # mfcc, labels 값이 list이므로 -> numpy array로 변경
  y = np.array(data["labels"])       

  return X, y

if __name__ == "__main__" :

  # load data
  X, y = load_data(DATASET_PATH)

  # split the data into train and test sets
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
  
  # build the network architecture
  model = keras.Sequential([
                            
      # input layer
      keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),  # data를 1차원으로 flatten

      # 1st hidden(dense) layer
      keras.layers.Dense(512, activation="relu"),  

      # 2nd hidden layer
      keras.layers.Dense(256, activation="relu"),

      # 3rd hidden layer
      keras.layers.Dense(64, activation="relu"),

      # output layer
      keras.layers.Dense(10, activation="softmax")
  ])

  # compile model(network)
  optimizer = keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(optimizer=optimizer,
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])
  
  model.summary()

  # train model
  model.fit(X_train, y_train,
            validation_data=(X_test, y_test),
            batch_size=32,
            epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1690)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               865792
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 219/219 [==============================] - 5s 22ms/step - loss: 14.3664 - accuracy: 0.2459 - val_loss: 2.3788 - val_accuracy: 0.1727
# Epoch 2/50
# 219/219 [==============================] - 4s 18ms/step - loss: 2.1458 - accuracy: 0.2428 - val_loss: 2.1967 - val_accuracy: 0.2554
# Epoch 3/50
# 219/219 [==============================] - 4s 19ms/step - loss: 1.9559 - accuracy: 0.3124 - val_loss: 2.1342 - val_accuracy: 0.2928
# Epoch 4/50
# 219/219 [==============================] - 4s 17ms/step - loss: 1.8434 - accuracy: 0.3587 - val_loss: 2.1437 - val_accuracy: 0.3188
# Epoch 5/50
# 219/219 [==============================] - 4s 17ms/step - loss: 1.7747 - accuracy: 0.3837 - val_loss: 2.0963 - val_accuracy: 0.3501
# Epoch 6/50
# 219/219 [==============================] - 4s 18ms/step - loss: 1.6971 - accuracy: 0.3990 - val_loss: 2.0195 - val_accuracy: 0.3998
# Epoch 7/50
# 219/219 [==============================] - 4s 19ms/step - loss: 1.5737 - accuracy: 0.4809 - val_loss: 2.0090 - val_accuracy: 0.4015
# Epoch 8/50
# 219/219 [==============================] - 4s 19ms/step - loss: 1.4746 - accuracy: 0.5017 - val_loss: 1.9056 - val_accuracy: 0.4198
# Epoch 9/50
# 219/219 [==============================] - 4s 18ms/step - loss: 1.4197 - accuracy: 0.5017 - val_loss: 1.9252 - val_accuracy: 0.4285
# Epoch 10/50
# 219/219 [==============================] - 4s 18ms/step - loss: 1.3637 - accuracy: 0.5181 - val_loss: 1.8873 - val_accuracy: 0.4095
# Epoch 11/50
# 219/219 [==============================] - 4s 18ms/step - loss: 1.2760 - accuracy: 0.5396 - val_loss: 1.9220 - val_accuracy: 0.4425
# Epoch 12/50
# 219/219 [==============================] - 4s 17ms/step - loss: 1.2985 - accuracy: 0.5416 - val_loss: 2.0312 - val_accuracy: 0.4612
# Epoch 13/50
# 219/219 [==============================] - 4s 19ms/step - loss: 1.2412 - accuracy: 0.5693 - val_loss: 1.8712 - val_accuracy: 0.4525
# Epoch 14/50
# 219/219 [==============================] - 3s 15ms/step - loss: 1.1455 - accuracy: 0.5931 - val_loss: 1.8631 - val_accuracy: 0.4415
# Epoch 15/50
# 219/219 [==============================] - 3s 16ms/step - loss: 1.1287 - accuracy: 0.6044 - val_loss: 1.8295 - val_accuracy: 0.4705
# Epoch 16/50
# 219/219 [==============================] - 3s 15ms/step - loss: 1.0839 - accuracy: 0.6142 - val_loss: 1.8664 - val_accuracy: 0.4888
# Epoch 17/50
# 219/219 [==============================] - 3s 15ms/step - loss: 1.0108 - accuracy: 0.6397 - val_loss: 1.8585 - val_accuracy: 0.4645
# Epoch 18/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.9439 - accuracy: 0.6564 - val_loss: 1.8199 - val_accuracy: 0.4938
# Epoch 19/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.9197 - accuracy: 0.6668 - val_loss: 1.8257 - val_accuracy: 0.5142
# Epoch 20/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.9135 - accuracy: 0.6684 - val_loss: 1.9590 - val_accuracy: 0.4995
# Epoch 21/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.8419 - accuracy: 0.6956 - val_loss: 1.9419 - val_accuracy: 0.5102
# Epoch 22/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.7775 - accuracy: 0.7117 - val_loss: 1.9702 - val_accuracy: 0.4935
# Epoch 23/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.7727 - accuracy: 0.7124 - val_loss: 1.9015 - val_accuracy: 0.5295
# Epoch 24/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.6938 - accuracy: 0.7415 - val_loss: 1.9355 - val_accuracy: 0.5295
# Epoch 25/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.6746 - accuracy: 0.7483 - val_loss: 1.9653 - val_accuracy: 0.5298
# Epoch 26/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.6221 - accuracy: 0.7680 - val_loss: 2.0159 - val_accuracy: 0.5512
# Epoch 27/50
# 219/219 [==============================] - 4s 18ms/step - loss: 0.6561 - accuracy: 0.7552 - val_loss: 1.8911 - val_accuracy: 0.5365
# Epoch 28/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.5895 - accuracy: 0.7841 - val_loss: 2.0567 - val_accuracy: 0.5495
# Epoch 29/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.5782 - accuracy: 0.7872 - val_loss: 2.0434 - val_accuracy: 0.5485
# Epoch 30/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.5285 - accuracy: 0.8059 - val_loss: 2.0218 - val_accuracy: 0.5512
# Epoch 31/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.5015 - accuracy: 0.8159 - val_loss: 2.0855 - val_accuracy: 0.5532
# Epoch 32/50
# 219/219 [==============================] - 3s 15ms/step - loss: 0.4939 - accuracy: 0.8198 - val_loss: 2.1106 - val_accuracy: 0.5535
# Epoch 33/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.4840 - accuracy: 0.8208 - val_loss: 2.1066 - val_accuracy: 0.5468
# Epoch 34/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.4648 - accuracy: 0.8285 - val_loss: 2.1616 - val_accuracy: 0.5428
# Epoch 35/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.4619 - accuracy: 0.8293 - val_loss: 2.3336 - val_accuracy: 0.5612
# Epoch 36/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.4281 - accuracy: 0.8490 - val_loss: 2.1130 - val_accuracy: 0.5699
# Epoch 37/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.3721 - accuracy: 0.8634 - val_loss: 2.0739 - val_accuracy: 0.5709
# Epoch 38/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.3676 - accuracy: 0.8638 - val_loss: 2.2816 - val_accuracy: 0.5522
# Epoch 39/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.3820 - accuracy: 0.8654 - val_loss: 2.2465 - val_accuracy: 0.5759
# Epoch 40/50
# 219/219 [==============================] - 3s 14ms/step - loss: 0.3179 - accuracy: 0.8887 - val_loss: 2.2467 - val_accuracy: 0.5679
# Epoch 41/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.2860 - accuracy: 0.8942 - val_loss: 2.2619 - val_accuracy: 0.5655
# Epoch 42/50
# 219/219 [==============================] - 3s 16ms/step - loss: 0.2928 - accuracy: 0.8909 - val_loss: 2.2827 - val_accuracy: 0.5652
# Epoch 43/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.2819 - accuracy: 0.8995 - val_loss: 2.2955 - val_accuracy: 0.5622
# Epoch 44/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.2976 - accuracy: 0.8921 - val_loss: 2.2878 - val_accuracy: 0.5642
# Epoch 45/50
# 219/219 [==============================] - 4s 16ms/step - loss: 0.2957 - accuracy: 0.8924 - val_loss: 2.4501 - val_accuracy: 0.5725
# Epoch 46/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.2237 - accuracy: 0.9234 - val_loss: 2.5227 - val_accuracy: 0.5662
# Epoch 47/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.2030 - accuracy: 0.9243 - val_loss: 2.4332 - val_accuracy: 0.5819
# Epoch 48/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.2191 - accuracy: 0.9248 - val_loss: 2.3543 - val_accuracy: 0.5839
# Epoch 49/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.2168 - accuracy: 0.9229 - val_loss: 2.4333 - val_accuracy: 0.5842
# Epoch 50/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.1643 - accuracy: 0.9453 - val_loss: 2.4884 - val_accuracy: 0.5869
